# %% [markdown]
# ## Estabelecimentos de Educação

# %%
from pathlib import Path

import pandas as pd

base_dir = Path(r"c:\Users\clebe\OneDrive\Documentos\USP\7 semestre\governo-aberto\projeto-gov-aberto")
input_csv = base_dir / "dados" / "escolas_sao_vicente_inep.csv"

df_escolas = pd.read_csv(input_csv, encoding="utf-8-sig")
colunas_analise = [
    "Localização",
    "Categoria Administrativa",
    "Dependência Administrativa",
    "Porte da Escola",
    "Etapas e Modalidade de Ensino Oferecidas",
]

for coluna in colunas_analise:
    print(f"\n=== {coluna} ===")
    contagem = df_escolas[coluna].fillna("Não Informado").astype(str).str.strip().value_counts(dropna=False)
    print(contagem.to_string())
# Out:
# === Localização ===
# Localização
# Urbana    241
#
# === Categoria Administrativa ===
# Categoria Administrativa
# Pública    144
# Privada     97
#
# === Dependência Administrativa ===
# Dependência Administrativa
# Municipal    113
# Privada       97
# Estadual      31
#
# === Porte da Escola ===
# Porte da Escola
# Entre 51 e 200 matrículas de escolarização      83
# Entre 201 e 500 matrículas de escolarização     56
# Até 50 matrículas de escolarização              34
# Entre 501 e 1000 matrículas de escolarização    26
# Não Informado                                   23
# Mais de 1000 matrículas de escolarização        18
# Escola sem matrícula de escolarização            1
#
# === Etapas e Modalidade de Ensino Oferecidas ===
# Etapas e Modalidade de Ensino Oferecidas
# Educação Infantil                                                                      97
# Educação Infantil, Ensino Fundamental                                                  34
# Ensino Fundamental                                                                     29
# Não Informado                                                                          24
# Ensino Fundamental, Ensino Médio                                                       15
# Educação Infantil, Ensino Fundamental, Ensino Médio                                    11
# Educação Infantil, Ensino Fundamental, Educação de Jovens Adultos                       7
# Ensino Fundamental, Ensino Médio, Educação Profissional                                 7
# Ensino Fundamental, Educação de Jovens Adultos                                          6
# Educação de Jovens Adultos                                                              4
# Ensino Médio, Educação Profissional                                                     3
# Educação Profissional                                                                   2
# Ensino Fundamental, Ensino Médio, Educação Profissional, Educação de Jovens Adultos     1
# Ensino Fundamental, Ensino Médio, Educação de Jovens Adultos                            1

# %% [markdown]
# ## Estabelecimentos de Saúde

# %%
from pathlib import Path

import pandas as pd

base_dir = Path(r"c:\Users\clebe\OneDrive\Documentos\USP\7 semestre\governo-aberto\projeto-gov-aberto")
input_csv = base_dir / "dados" / "Estabelecimentos_saude_sao_vicente_cnes.xlsx - Planilha1.csv"

df_saude = pd.read_csv(input_csv, encoding="utf-8-sig")
colunas_analise_saude = [
    "DS_ESFERA_ADMINISTRATIVA",
    "DS_TURNO_ATENDIMENTO",
    "ST_CENTRO_CIRURGICO",
    "ST_CENTRO_OBSTETRICO",
    "ST_CENTRO_NEONATAL",
    "ST_ATEND_HOSPITALAR",
    "ST_SERVICO_APOIO",
    "ST_ATEND_AMBULATORIAL",
    "CO_AMBULATORIAL_SUS",
]

for coluna in colunas_analise_saude:
    print(f"\n=== {coluna} ===")
    contagem = df_saude[coluna].fillna("Não Informado").astype(str).str.strip().value_counts(dropna=False)
    print(contagem.to_string())
# Out:
# === DS_ESFERA_ADMINISTRATIVA ===
# DS_ESFERA_ADMINISTRATIVA
# MUNICIPAL    422
# ESTADUAL       5
#
# === DS_TURNO_ATENDIMENTO ===
# DS_TURNO_ATENDIMENTO
# ATENDIMENTOS NOS TURNOS DA MANHA E A TARDE                                            310
# ATENDIMENTO NOS TURNOS DA MANHA, TARDE E NOITE                                         57
# ATENDIMENTO CONTINUO DE 24 HORAS/DIA (PLANTAO:INCLUI SABADOS, DOMINGOS E FERIADOS)     28
# ATENDIMENTO SOMENTE A TARDE                                                            22
# ATENDIMENTO SOMENTE PELA MANHA                                                          7
# ATENDIMENTO COM TURNOS INTERMITENTES                                                    3
#
# === ST_CENTRO_CIRURGICO ===
# ST_CENTRO_CIRURGICO
# 0.0              391
# Não Informado     31
# 1.0                5
#
# === ST_CENTRO_OBSTETRICO ===
# ST_CENTRO_OBSTETRICO
# 0.0              394
# Não Informado     31
# 1.0                2
#
# === ST_CENTRO_NEONATAL ===
# ST_CENTRO_NEONATAL
# 0.0              394
# Não Informado     31
# 1.0                2
#
# === ST_ATEND_HOSPITALAR ===
# ST_ATEND_HOSPITALAR
# 0.0              391
# Não Informado     31
# 1.0                5
#
# === ST_SERVICO_APOIO ===
# ST_SERVICO_APOIO
# 1.0    326
# 0.0    101
#
# === ST_ATEND_AMBULATORIAL ===
# ST_ATEND_AMBULATORIAL
# 0.0    420
# 1.0      7
#
# === CO_AMBULATORIAL_SUS ===
# CO_AMBULATORIAL_SUS
# NAO    355
# SIM     72
